# %%
import safe
# Out:
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality

# %%
smi = "	OC[C@@H](O1)[C@@H](O)[C@H](O)[C@@H]2[C@@H]1c3c(O)c(OC)c(O)cc3C(=O)O2"

# %%
safe.encode(smi)
# Out:
# '[C@H]15O[C@H]2c3c(cc(O)c4c3O)C(=O)O[C@@H]2[C@@H](O)[C@@H]1O.OC5.O4C'

# %%
safe.encode(smi, ignore_stereo=True)
# Out:
# 'C15OC2c3c(cc(O)c4c3O)C(=O)OC2C(O)C1O.OC5.O4C'
