# %%
import torch

# 1. 加载文件
# 注意：如果你在没有 GPU 的节点（如 login node）上，必须加 map_location='cpu'
try:
    content = torch.load('finetune_data/crossdock_dataset/split_by_name.pt', map_location=torch.device('cpu'))
except Exception as e:
    print(f"加载失败: {e}")

# %%
content
# Out:
# {'train': [('DYR_STAAU_2_158_0/4xe6_X_rec_3fqc_55v_lig_tt_docked_4_pocket10.pdb',
#    'DYR_STAAU_2_158_0/4xe6_X_rec_3fqc_55v_lig_tt_docked_4.sdf'),
#   ('TRY1_BOVIN_66_246_0/1k1j_A_rec_1yp9_uiz_lig_tt_docked_1_pocket10.pdb',
#    'TRY1_BOVIN_66_246_0/1k1j_A_rec_1yp9_uiz_lig_tt_docked_1.sdf'),
#   ('HYES_HUMAN_230_551_0/5ai4_A_rec_5am0_lws_lig_tt_min_0_pocket10.pdb',
#    'HYES_HUMAN_230_551_0/5ai4_A_rec_5am0_lws_lig_tt_min_0.sdf'),
#   ('CHK2_HUMAN_210_526_0/4a9s_A_rec_4bdk_rqq_lig_tt_min_0_pocket10.pdb',
#    'CHK2_HUMAN_210_526_0/4a9s_A_rec_4bdk_rqq_lig_tt_min_0.sdf'),
#   ('FLA_STRCT_1_299_0/1rqp_A_rec_2v7v_5fd_lig_tt_docked_0_pocket10.pdb',
#    'FLA_STRCT_1_299_0/1rqp_A_rec_2v7v_5fd_lig_tt_docked_0.sdf'),
#   ('ESR1_HUMAN_300_553_0/5acc_A_rec_5acc_ke9_lig_tt_min_0_pocket10.pdb',
#    'ESR1_HUMAN_300_553_0/5acc_A_rec_5acc_ke9_lig_tt_min_0.sdf'),
#   ('MCR_HUMAN_724_984_ligBind_0/1y9r_A_rec_2a3i_c0r_lig_tt_docked_0_pocket10.pdb',
# ...
